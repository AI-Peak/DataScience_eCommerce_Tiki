# %%
import requests

# Default
url = "https://tiki.vn/api/personalish/v1/blocks/listings"


# @ Change Referer:
# Remain: https://tiki.vn/
# Change: nha-sach-tiki & 8322 (Remain 'c')
# Example: "https://tiki.vn/thiet-bi-kts-phu-kien-so/c1815"

headers = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) Gecko/20100101 Firefox/147.0",
    "Accept": "application/json, text/plain, */*",
    "Referer": "https://tiki.vn/nha-sach-tiki/c8322"
}

# Change:
# - Category
# - Page
# - Sort
# - Urlkey
# - limit: default

params = {
    "category": 8322,
    "page": 1,
    "limit": 40,
    "sort": "top_seller",
    "urlKey": "nha-sach-tiki"
}

r = requests.get(url, headers=headers, params=params, timeout=30)
print(r.status_code)
print(r.json().keys())
# Out:
# 200
# dict_keys(['block', 'data', 'paging', 'filters', 'amplitude', 'sort_options', 'widgets', 'experiment_variants', 'model_debug', 'trace_id', 'items'])

# %%
# Run to check the data
j = r.json()

type(j["data"]), len(j["data"]) if isinstance(j["data"], list) else j["data"].keys()
# Out:
# (list, 40)

# %%
type(j["items"]), len(j["items"]) if isinstance(j["items"], list) else j["items"].keys()
# Out:
# (list, 0)

# %%
# Check the features
if isinstance(j["data"], list) and len(j["data"]) > 0:
    sample = j["data"][0]
else:
    sample = j["items"][0]

sample.keys()
# Out:
# dict_keys(['id', 'sku', 'name', 'url_key', 'url_path', 'type', 'author_name', 'book_cover', 'brand_name', 'short_description', 'price', 'list_price', 'badges', 'badges_new', 'discount', 'discount_rate', 'rating_average', 'review_count', 'order_count', 'favourite_count', 'thumbnail_url', 'thumbnail_width', 'thumbnail_height', 'freegift_items', 'has_ebook', 'inventory_status', 'is_visible', 'productset_id', 'productset_group_name', 'seller', 'is_flower', 'is_gift_card', 'inventory', 'url_attendant_input_form', 'option_color', 'stock_item', 'salable_type', 'seller_product_id', 'installment_info', 'url_review', 'bundle_deal', 'quantity_sold', 'tiki_live', 'original_price', 'shippable', 'impression_info', 'advertisement', 'availability', 'primary_category_path', 'product_reco_score', 'seller_id', 'visible_impression_info', 'badges_v3'])

# %%
import pandas as pd

def normalize_quantity_sold(x):
    if isinstance(x, dict):
        return x.get("value")
    return x

products = j["data"]

rows = []
for p in products:
    rows.append({
        # ===== Identity =====
        "id": p.get("id"),
        "sku": p.get("sku"),
        "name": p.get("name"),
        "type": p.get("type"),
        "url_path": p.get("url_path"),

        # ===== Author / Brand =====
        "author_name": p.get("author_name"),
        "brand_name": p.get("brand_name"),

        # ===== Product grouping =====
        "productset_id": p.get("productset_id"),
        "productset_group_name": p.get("productset_group_name"),
        "primary_category_path": p.get("primary_category_path"),

        # ===== Pricing =====
        "price": p.get("price"),
        "list_price": p.get("list_price"),
        "original_price": p.get("original_price"),
        "discount": p.get("discount"),
        "discount_rate": p.get("discount_rate"),
        "bundle_deal": p.get("bundle_deal"),

        # ===== Trust / Social proof =====
        "rating_average": p.get("rating_average"),
        "review_count": p.get("review_count"),
        "order_count": p.get("order_count"),
        "favourite_count": p.get("favourite_count"),

        # ===== Badges =====
        "badges": p.get("badges"),
        "badges_new": p.get("badges_new"),
        "badges_v3": p.get("badges_v3"),

        # ===== Sales / Exposure =====
        "quantity_sold": normalize_quantity_sold(p.get("quantity_sold")),
        "product_reco_score": p.get("product_reco_score"),
        "advertisement": p.get("advertisement"),

        # ===== Inventory / Availability =====
        "inventory_status": p.get("inventory_status"),
        "inventory": p.get("inventory"),
        "stock_item": p.get("stock_item"),
        "salable_type": p.get("salable_type"),
        "availability": p.get("availability"),
        "shippable": p.get("shippable"),

        # ===== Seller =====
        "seller": p.get("seller"),
        "seller_id": p.get("seller_id"),
        "seller_product_id": p.get("seller_product_id"),

        # ===== Finance =====
        "is_gift_card": p.get("is_gift_card"),
        "installment_info": p.get("installment_info"),

        # ===== Full URL =====
        "url": "https://tiki.vn/" + (p.get("url_path") or "")
    })

df = pd.DataFrame(rows)
df.head()
# Out:
#           id            sku  \
# 0  278967562  7133308969741
# 1  278948895  8645560580853
# 2  278901566  4174902861053
# 3  278879928  5273983117908
# 4  278874643  5490576331288
#
#                                                 name type  \
# 0           Monster - Deluxe Edition –  [Chọn Tập Lẻ
# 1  Tuyển Tập Kiệt Tác Fujiko F Fujio - F The Best...
# 2                                   Sách Đời Gió Bụi
# 3  Sách Nếu Như Không Thể Nói Nếu Như & Có Ai Giữ...
# 4         Sách Đại Pháp Sư Của Thư Viện [Chọn Tập Lẻ
#
#                                             url_path author_name brand_name  \
# 0  monster-deluxe-edition-chon-tap-le-p278967562....
# 1  tuyen-tap-kiet-tac-fujiko-f-fujio-f-the-best-t...
# 2    sach-doi-gio-bui-p278901566.html?spid=278901597
# 3  sach-neu-nhu-khong-the-noi-neu-nhu-co-ai-giu-g...
# 4  sach-dai-phap-su-cua-thu-vien-chon-tap-le-p278...
#
#    productset_id productset_group_name       primary_category_path  ...  \
# 0            253                                 1/2/8322/316/1084  ...
# 1            253                                 1/2/8322/316/1084  ...
# 2            251                        1/2/8322/316/839/844/67996  ...
# 3            251                        1/2/8322/316/839/845/68000  ...
# 4            253                                 1/2/8322/316/1084  ...
#
#    stock_item  salable_type  availability  shippable  seller  seller_id  \
# 0        None                           1       True    None          1
# 1        None                           1       True    None          1
# 2        None                           1       True    None          1
# 3        None                           1       True    None          1
# 4        None                           1       True    None          1
#
#    seller_product_id  is_gift_card  installment_info  \
# 0          278706877         False              None
# 1          278948896         False              None
# 2          278901597         False              None
# 3          278882152         False              None
# 4          279082235         False              None
#
#                                                  url
# 0  https://tiki.vn/monster-deluxe-edition-chon-ta...
# 1  https://tiki.vn/tuyen-tap-kiet-tac-fujiko-f-fu...
# 2  https://tiki.vn/sach-doi-gio-bui-p278901566.ht...
# 3  https://tiki.vn/sach-neu-nhu-khong-the-noi-neu...
# 4  https://tiki.vn/sach-dai-phap-su-cua-thu-vien-...
#
# [5 rows x 38 columns]

# %%
df[["name", "type", "price", "quantity_sold", "rating_average"]].head(10)
# Out:
#                                                 name type   price  \
# 0           Monster - Deluxe Edition –  [Chọn Tập Lẻ       118750
# 1  Tuyển Tập Kiệt Tác Fujiko F Fujio - F The Best...       190000
# 2                                   Sách Đời Gió Bụi       245000
# 3  Sách Nếu Như Không Thể Nói Nếu Như & Có Ai Giữ...       258750
# 4         Sách Đại Pháp Sư Của Thư Viện [Chọn Tập Lẻ        42750
# 5  Sách Cô Bé Hàng Xóm Và Bốn Viên Kẹo (Nguyễn Nh...       156000
# 6         Sách Tính Bản Ác (M. Scott Peck) - Tuệ Tri       126000
# 7  Sách Dragon Quest - Cuộc Phiêu Lưu Của Dũng Sĩ...        65550
# 8   Sách Dragon Ball - 7 Viên Ngọc Rồng [Chọn Tập Lẻ        28500
# 9         Bộ Sách Quiz! Khoa Học Kì Thú [Chọn Tập Lẻ        60000
#
#    quantity_sold  rating_average
# 0            461             5.0
# 1            177             4.7
# 2            181             5.0
# 3            296             5.0
# 4             39             0.0
# 5            598             5.0
# 6            251             4.6
# 7            153             5.0
# 8              8             4.8
# 9            103             0.0

# %%
# Check the shape of data
df.shape
# Out:
# (40, 38)

# %%
# Export to .csv file
df.to_csv("tiki_books_1.csv", index=False, encoding="utf-8-sig")

# %%
# Check page
j["paging"]
# Out:
# {'current_page': 3,
#  'from': 81,
#  'last_page': 50,
#  'per_page': 40,
#  'to': 120,
#  'total': 2000}

# %%
import time
import requests

all_rows = []

def normalize_quantity_sold(x):
    if isinstance(x, dict):
        return x.get("value")
    return x

for page in range(1, 3):   # change 6 -> more pages if you want
    params["page"] = page

    r = requests.get(url, headers=headers, params=params, timeout=30)
    r.raise_for_status()
    j = r.json()

    products = j["data"]
    if not products:   # stop if empty
        break

    for p in products:
        all_rows.append({
            # ===== Identity =====
            "id": p.get("id"),
            "sku": p.get("sku"),
            "name": p.get("name"),
            "type": p.get("type"),
            "url_path": p.get("url_path"),

            # ===== Author / Brand =====
            "author_name": p.get("author_name"),
            "brand_name": p.get("brand_name"),

            # ===== Product grouping =====
            "productset_id": p.get("productset_id"),
            "productset_group_name": p.get("productset_group_name"),
            "primary_category_path": p.get("primary_category_path"),

            # ===== Pricing =====
            "price": p.get("price"),
            "list_price": p.get("list_price"),
            "original_price": p.get("original_price"),
            "discount": p.get("discount"),
            "discount_rate": p.get("discount_rate"),
            "bundle_deal": p.get("bundle_deal"),

            # ===== Trust / Social proof =====
            "rating_average": p.get("rating_average"),
            "review_count": p.get("review_count"),
            "order_count": p.get("order_count"),
            "favourite_count": p.get("favourite_count"),

            # ===== Badges =====
            "badges": p.get("badges"),
            "badges_new": p.get("badges_new"),
            "badges_v3": p.get("badges_v3"),

            # ===== Sales / Exposure =====
            "quantity_sold": normalize_quantity_sold(p.get("quantity_sold")),
            "product_reco_score": p.get("product_reco_score"),
            "advertisement": p.get("advertisement"),

            # ===== Inventory / Availability =====
            "inventory_status": p.get("inventory_status"),
            "inventory": p.get("inventory"),
            "stock_item": p.get("stock_item"),
            "salable_type": p.get("salable_type"),
            "availability": p.get("availability"),
            "shippable": p.get("shippable"),

            # ===== Seller =====
            "seller": p.get("seller"),
            "seller_id": p.get("seller_id"),
            "seller_product_id": p.get("seller_product_id"),

            # ===== Finance =====
            "is_gift_card": p.get("is_gift_card"),
            "installment_info": p.get("installment_info"),

            # ===== Full URL =====
            "url": "https://tiki.vn/" + (p.get("url_path") or "")
        })

    time.sleep(1)  # polite crawling

df_all = pd.DataFrame(all_rows)
df_all.shape, df_all.head()
# Out:
# ((80, 38),
#            id            sku  \
#  0  278967562  7133308969741
#  1  278948895  8645560580853
#  2  278901566  4174902861053
#  3  278879928  5273983117908
#  4  278874643  5490576331288
#
#                                                  name type  \
#  0           Monster - Deluxe Edition –  [Chọn Tập Lẻ
#  1  Tuyển Tập Kiệt Tác Fujiko F Fujio - F The Best...
#  2                                   Sách Đời Gió Bụi
#  3  Sách Nếu Như Không Thể Nói Nếu Như & Có Ai Giữ...
#  4         Sách Đại Pháp Sư Của Thư Viện [Chọn Tập Lẻ
#
#                                              url_path author_name brand_name  \
#  0  monster-deluxe-edition-chon-tap-le-p278967562....
#  1  tuyen-tap-kiet-tac-fujiko-f-fujio-f-the-best-t...
#  2    sach-doi-gio-bui-p278901566.html?spid=278901597
#  3  sach-neu-nhu-khong-the-noi-neu-nhu-co-ai-giu-g...
#  4  sach-dai-phap-su-cua-thu-vien-chon-tap-le-p278...
#
#     productset_id productset_group_name       primary_category_path  ...  \
#  0            253                                 1/2/8322/316/1084  ...
#  1            253                                 1/2/8322/316/1084  ...
#  2            251                        1/2/8322/316/839/844/67996  ...
#  3            251                        1/2/8322/316/839/845/68000  ...
#  4            253                                 1/2/8322/316/1084  ...
#
#     stock_item  salable_type  availability  shippable  seller  seller_id  \
#  0        None                           1       True    None          1
#  1        None                           1       True    None          1
#  2        None                           1       True    None          1
#  3        None                           1       True    None          1
#  4        None                           1       True    None          1
#
#     seller_product_id  is_gift_card  installment_info  \
#  0          278706877         False              None
#  1          278948896         False              None
#  2          278901597         False              None
#  3          278882152         False              None
#  4          279082235         False              None
#
#                                                   url
#  0  https://tiki.vn/monster-deluxe-edition-chon-ta...
#  1  https://tiki.vn/tuyen-tap-kiet-tac-fujiko-f-fu...
#  2  https://tiki.vn/sach-doi-gio-bui-p278901566.ht...
#  3  https://tiki.vn/sach-neu-nhu-khong-the-noi-neu...
#  4  https://tiki.vn/sach-dai-phap-su-cua-thu-vien-...
#
#  [5 rows x 38 columns])
